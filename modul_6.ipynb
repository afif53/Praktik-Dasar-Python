# %% [markdown]
# <a href="https://colab.research.google.com/github/afif53/Praktik-Dasar-Python/blob/main/modul_6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#a) Fungsi
#  Pendefinisan fungsi di dalam Python dilakukan dengan menggunakan kata kunci
#   "def".
#   Contoh:

def sisabagi(a, b):
    hasil = a % b
    return hasil

h1 = sisabagi(10, 3)
h2 = sisabagi(14, 4)
h3 = sisabagi(17, 7)

print(h1)
print(h2)
print(h3)

# Jika ingin mendefinisikan parameter default, tempatkan parameter tsb sebagai
# parameter paling akhir dari daftar parameter.
# Contoh:

def write(s, newline=True):
    print(s, end='')
    if newline: print()

write('Pemrograman ', False); write("Python")

write('Pemrograman '); write("Python")

#Variabel yang digunakan di dalam fungsi selalu bersifat lokal. Untuk mengakses
#  variabel "global" dari suatu fungsi, gunakan kata kunci "global"
#   Contoh:

def write(s, newline=True):
    print(s, end='')
    if newline: print()

write('Pemrograman ', False); write("Python")

write('Pemrograman '); write("Python")

# Variabel yang digunakan di dalam fungsi selalu bersifat lokal. Untuk mengakses
# variabel "global" dari suatu fungsi, gunakan kata kunci "global"
# Contoh variabel global
count = 0

# Fungsi yang mengakses variabel global
def increment():
    global count
    count += 1 # mengubah nilai variabel global

# menampilkan nilai awal variabel global
print(count)

# memanggil fungsi increment()
increment()

# menampilkan nilai count
# setelah pemanggilan fungsi increment()
print(count)
increment()
print(count)

# Contoh kode program yang menggunakan fungsi:

import datetime as dt

def getisoformat(date):
    return dt.date.isoformat(date)

def day(date):
    datestr = getisoformat(date)
    return int(datestr[8:])

def month(date):
    datestr = getisoformat(date)
    return int(datestr[5:7])

def year(date):
    datestr = getisoformat(date)
    return int(datestr[:4])

def main():
    today = dt.date.today()
    print(getisoformat(today))
    print("\nHari\t: %d" % day(today))
    print("Bulan\t: %d" % month(today))
    print("Tahun\t: %d" % year(today))

if __name__ == "__main__":
    main()
# Out:
# 1
# 2
# 3
# Pemrograman Python
# Pemrograman
# Python
# Pemrograman Python
# Pemrograman
# Python
# 0
# 1
# 2
# 2025-12-04
#
# Hari	: 4
# Bulan	: 12
# Tahun	: 2025
